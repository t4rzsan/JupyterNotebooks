# %% [markdown]
# # How to setup Jupyter
# This notebook describes how to install Jupyter Notebook on a Windows box.  The Jupyter is flaky so this is an attempt to put it all together in one place.
#
# # Installing Jupyter
# The easiest way too install Jupyter is through Anaconda.  Go to the Anaconda [download page](https://www.continuum.io/downloads) to install.
#
# After Anaconda has been installed, start Anaconda Navigator and launch Jupyter from there.  This will open a browser for an address similiar to http://localhost:8888 which shows you the home location of Jupyter on your system.  From here you can start new notebooks or edit existing ones.
#
# ## Change the Jupyter startup folder
# By default Jupyter starts from the C:\ root and it seems there is no way to go to another drive.  If you want Jupyter to start from another location, type the following into a cmd prompt:
#
#     jupyter notebook --generate-config
#
# This will generate a Jupyter config file for you.  Open the file in a text editor and change the line
#     #c.NotebookApp.notebook_dir = ''
# to
#     #c.NotebookApp.notebook_dir = 'd:\my-directory'
#
# It seems that Jupyter sometimes ignores the startup directory.  Alternatively you may start Jupyter Notebook in any given directory from the command prompt.
#
#     jupyter notebook --notebook-dir=d:\my-directory

# %% [markdown]
# # Tips and tricks
# ## Code in text
# If you want to show code with syntax highlighting in your text (as opposed to kernel code that you with to run), you can use three back ticks (\`\`\`).  You may also specify a language for syntax highlighting.
#
# For example this
#
# \`\`\`C#
# <pre>
# public class Foo
# {
#     private readonly int a = 42;
# }
# </pre>
# \`\`\`
#
# will output
# ```C#
# public class Foo
# {
#     private readonly int a = 42;
# }
# ```
#
# ## Static images
# If you want to display images in your notebook, put the images in a subfolder next to your .ypnb file.  Include them in markdown by using the HTML &lt;img> tag.  In the 'src' attribute _always_ prepend 'files' to the folder path if you are using relative paths, i.e.
# ```HTML
# <img src="files/my-subfolder/my-image.png">
# ```
# When prepending 'files', Jupyter will figure out the right path in both nbviewer and Github.
#
# ## Hiding code blocks in Jupyter
# You may want to hide your R or Python code blocks when distributing your Jupyter Notebooks to someone else.  This shows you a way to do this when exporting your notebook as HTML or showing your notebook in [nbviewer](https://nbviewer.jupyter.org/).
#
# Start by adding a "Raw NBConvert" block at the top of your notebook.
#
# Paste the following JavaScript and HTML into the block (shamelessly stolen from [elsewhere](http://chris-said.io/2016/02/13/how-to-make-polished-jupyter-presentations-with-optional-code-visibility/)).
#
# ```HTML
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>
# ```
#
# The code will put a "Show code"/"Hide code" buttom at the top of your notebook in nbviewer.  It will not work if showing the notebook in Github.
#
# The method is a bit clumsy by at the moment Jupyter does not support hiding the code.

# %% [markdown]
# ## LaTeX
# Jupyter markdown supports LaTeX blocks. You start and end an inline LaTeX block with \$, for example \$ \mu_x = a + b \cdot c^{x} \$.  Use double-\$ for a block.
#
# $$\mu_x = a + b \cdot c^{x}$$
